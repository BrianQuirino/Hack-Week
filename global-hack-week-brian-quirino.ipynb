# %% [markdown]
# <a href="https://www.kaggle.com/code/brianquirino/global-hack-week-brian-quirino?scriptVersionId=158353252" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# print hello world

# %%
print("hello, world!")
# Out:
# hello, world!

# %% [markdown]
# write a sorting method, I think make a list then sort it
